# %%
import pandas as pd

# %%
min_definition = pd.read_excel("./../data/interim/min-definition_2020-06-04.xlsx")
max_definition = pd.read_excel("./../data/interim/max-definition_2020-06-04.xlsx")
fully_covered  = pd.read_excel("./../data/interim/fully-covered-definition_2020-06-04.xlsx")

# %%
min_definition
# Out:
#    year iso3  stateness  successful_transition                   approach
# 0  2000  SRB  90.186891                      1  lowest common denominator
# 1  2003  GEO  42.121186                      1  lowest common denominator
# 2  2004  UKR  31.951018                      1  lowest common denominator
# 3  2005  KGZ  10.603574                      0  lowest common denominator
# 4  2009  MDA  13.582207                      0  lowest common denominator
# 5  2010  KGZ  14.582530                      0  lowest common denominator
# 6  2014  UKR  41.827017                      1  lowest common denominator

# %%
result = pd.concat([min_definition, fully_covered, max_definition], ignore_index=True)
result
# Out:
#     year iso3  stateness  successful_transition                   approach
# 0   2000  SRB  90.186891                      1  lowest common denominator
# 1   2003  GEO  42.121186                      1  lowest common denominator
# 2   2004  UKR  31.951018                      1  lowest common denominator
# 3   2005  KGZ  10.603574                      0  lowest common denominator
# 4   2009  MDA  13.582207                      0  lowest common denominator
# 5   2010  KGZ  14.582530                      0  lowest common denominator
# 6   2014  UKR  41.827017                      1  lowest common denominator
# 7   2000  SRB  89.319066                      1              fully covered
# 8   2003  GEO  54.014962                      1              fully covered
# 9   2004  UKR  67.685713                      1              fully covered
# 10  2005  KGZ  32.217639                      0              fully covered
# ...

# %%
result.to_excel("./../data/processed/stateness.xlsx", index=False)
