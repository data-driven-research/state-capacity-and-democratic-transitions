# %%
import pandas as pd

# %%
min_definition = pd.read_excel("./../data/interim/min-definition_2020-05-31.xlsx")
max_definition = pd.read_excel("./../data/interim/max-definition_2020-05-31.xlsx")
fully_covered  = pd.read_excel("./../data/interim/fully-covered-definition_2020-05-31.xlsx")

# %%
result = pd.concat([min_definition, fully_covered, max_definition], ignore_index=True)
result
# Out:
#     year iso3  stateness  successful_transition                   approach  \
# 0   2000  SRB  87.383146                      1  lowest common denominator
# 1   2003  GEO  45.710637                      1  lowest common denominator
# 2   2004  UKR  34.936429                      1  lowest common denominator
# 3   2005  KGZ  11.023552                      0  lowest common denominator
# 4   2009  MDA  15.703799                      0  lowest common denominator
# 5   2010  KGZ  15.739882                      0  lowest common denominator
# 6   2014  UKR  49.303153                      1  lowest common denominator
# 7   2000  SRB  91.777117                      1              fully covered
# 8   2003  GEO  43.441524                      1              fully covered
# 9   2004  UKR  58.979729                      1              fully covered
# 10  2005  KGZ  27.367605                      0              fully covered
# ...

# %%
result.to_excel("./../data/processed/stateness.xlsx", index=False)
